# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
df1 =pd.read_csv('first50runs.csv')

# %%
df2 =pd.read_csv('model1fiftytosixty.csv')

# %%
df3 =pd.read_csv('model1sixtytoseventy.csv')

# %%
df = pd.concat([df1[col], df2[col],df3[col]])

# %%
col = ['loss','accuracy','val_loss','val_accuracy']

# %%
df= df.reset_index()

# %%
plt.plot(df1['accuracy'])
plt.plot(df1['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(df1['loss'])
plt.plot(df1['val_loss'])
plt.title('model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
