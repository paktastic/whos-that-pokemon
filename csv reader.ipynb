# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt

# %%
df1 =pd.read_csv('advanced96/my_model_advanced96.csv')

# %%
df2 =pd.read_csv('advanced96/my_model_advanced96_30.csv')

# %%
df3 =pd.read_csv('advanced96/my_model_advanced96_60.csv')

# %%
df4 =pd.read_csv('advanced96/my_model_advanced96_100.csv')

# %%
df5 =pd.read_csv('advanced96/my_model_advanced96_130.csv')

# %%
df6 =pd.read_csv('advanced96/my_model_advanced96_150.csv')

# %%
col = ['loss','accuracy','val_loss','val_accuracy']

# %%
df = pd.concat([df1[col], df2[col],df3[col],df4[col],df5[col],df6[col]])

# %%
df= df.reset_index()

# %%
df
# Out:
#      index      loss  accuracy  val_loss  val_accuracy
# 0        0  4.685976  0.044113  4.327372      0.066635
# 1        1  3.978092  0.091445  3.829376      0.114746
# 2        2  3.769616  0.124628  3.533807      0.172841
# 3        3  3.615837  0.152499  3.412180      0.191845
# 4        4  3.454023  0.181584  3.367230      0.209286
# ..     ...       ...       ...       ...           ...
# 145     15  0.961090  0.728030  1.071989      0.738598
# 146     16  0.976012  0.727135  1.088786      0.736374
# 147     17  0.963620  0.729386  1.087568      0.744655
# 148     18  0.963569  0.727382  1.077299      0.741318
# 149     19  0.958061  0.730281  1.163205      0.725250
#
# [150 rows x 5 columns]

# %%
plt.plot(df['accuracy'])
plt.plot(df['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(df['loss'])
plt.plot(df['val_loss'])
plt.title('model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
